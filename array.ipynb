# %% [markdown]
# Array In PY

# %%
from array import *

# %%
n = int(input("Enter value of N "))

arr = array('i',[])

for i in range(0,n):
    arr.append(int(input("Enter value")))

for x in arr:
    print(x)
# Out:
# 1
# 3
# 5
# 6
# 3
